# %%
# Global Power Plant Database

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
dfAUS=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Global%20Power%20Plant%20Database/database_AUS.csv")

# %%
dfAUS.head()
# Out:
#   country country_long                   name   gppd_idnr  capacity_mw  \
# 0     AUS    Australia       Adelaide Airport  AUS0000433         0.11
# 1     AUS    Australia   Adelaide Showgrounds  AUS0000432         1.00
# 2     AUS    Australia       Albany Wind Farm  AUS0000065        21.60
# 3     AUS    Australia  Alice Springs Airport  AUS0000469         0.24
# 4     AUS    Australia           Amcor Gawler  AUS0000231         4.00
#
#    latitude  longitude primary_fuel  other_fuel1  other_fuel2  ...  \
# 0  -34.9387   138.5377        Solar          NaN          NaN  ...
# 1  -34.9453   138.5882        Solar          NaN          NaN  ...
# 2  -35.0641   117.7977         Wind          NaN          NaN  ...
# 3  -23.7966   133.8971        Solar          NaN          NaN  ...
# 4  -34.5509   138.7659          Oil          NaN          NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
dfIND=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Global%20Power%20Plant%20Database/database_IND.csv")

# %%
dfIND.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
dfUSA=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML_-Datasets/main/Global%20Power%20Plant%20Database/database_USA.csv")

# %%
dfUSA.head()
# Out:
#   country              country_long                            name  \
# 0     USA  United States of America  10 Briggs Solar NG  LLC (East)
# 1     USA  United States of America      100 Brook Hill Drive Solar
# 2     USA  United States of America      1001 Ebenezer Church Solar
# 3     USA  United States of America             1008 Matthews Solar
# 4     USA  United States of America               1009 Yadkin Solar
#
#     gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 0  USA0062781          0.0   41.6327   -71.4963          NaN         NaN
# 1  USA0063292          2.0   41.0930   -73.9828        Solar         NaN
# 2  USA0063444          0.0   36.2838   -80.8434          NaN         NaN
# 3  USA0063447          0.0   36.2167   -80.5525          NaN         NaN
# 4  USA0063445          0.0   36.1475   -80.6561          NaN         NaN
#
#   other_fuel2  ... year_of_capacity_data  generation_gwh_2013  \
# ...

# %%
df=pd.DataFrame()

# %%
df=pd.concat( (dfAUS,dfIND,dfUSA))

# %%
df.head(1000)
# Out:
#     country country_long                    name   gppd_idnr  capacity_mw  \
# 0       AUS    Australia        Adelaide Airport  AUS0000433         0.11
# 1       AUS    Australia    Adelaide Showgrounds  AUS0000432         1.00
# 2       AUS    Australia        Albany Wind Farm  AUS0000065        21.60
# 3       AUS    Australia   Alice Springs Airport  AUS0000469         0.24
# 4       AUS    Australia            Amcor Gawler  AUS0000231         4.00
# ..      ...          ...                     ...         ...          ...
# 483     IND        India                MOYAGCHU  IND0000274         4.00
# 484     IND        India                   MOYAR  IND0000275        36.00
# 485     IND        India  MRMPL Mudari Wind Farm  WRI1026348        20.00
# 486     IND        India          MSPL Wind Farm  WRI1026070        78.90
# 487     IND        India           MUDHOL CEMENT  WRI1019927        50.00
#
#      latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# ...

# %%
df.shape
# Out:
# (13298, 27)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13298 entries, 0 to 11878
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   13298 non-null  object
#  1   country_long              13298 non-null  object
#  2   name                      13298 non-null  object
#  3   gppd_idnr                 13298 non-null  object
#  4   capacity_mw               13292 non-null  float64
#  5   latitude                  13220 non-null  float64
#  6   longitude                 13220 non-null  float64
#  7   primary_fuel              11294 non-null  object
#  8   other_fuel1               1628 non-null   object
#  9   other_fuel2               270 non-null    object
#  10  other_fuel3               92 non-null     object
#  11  commissioning_year        10654 non-null  float64
#  12  owner                     12705 non-null  object
# ...

# %%
df.describe()
# Out:
#         capacity_mw      latitude     longitude  commissioning_year  wepp_id  \
# count  13292.000000  13220.000000  13220.000000        10654.000000      0.0
# mean     117.738717     35.053213    -73.794217         1998.184904      NaN
# std      347.169038     15.444195     62.868834           24.017781      NaN
# min        0.000000    -42.888300   -171.712400         1896.000000      NaN
# 25%        1.500000     33.901700   -104.659875         1988.000000      NaN
# 50%        5.500000     38.389750    -87.346000         2008.000000      NaN
# 75%       52.725000     42.175125    -75.475925         2015.000000      NaN
# max     6809.000000    425.246100    153.434100         2020.000000      NaN
#
#        year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# count                12860.0          7170.000000          7534.000000
# mean                  2019.0           563.383222           635.739731
# ...

# %%
# Analysis and Visualization

# %%
df.country_long.nunique()
# Out:
# 3

# %%
countries_plant=df.country_long.value_counts().head(50)

# %%
countries_plant
# Out:
# country_long
# United States of America    11879
# India                         907
# Australia                     512
# Name: count, dtype: int64

# %%
sns.set_style("whitegrid")
sns.countplot(x="primary_fuel", data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='count'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='capacity_mw',y='generation_gwh_2013',data=df)
# Out:
# <Axes: xlabel='capacity_mw', ylabel='generation_gwh_2013'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='capacity_mw',y='generation_gwh_2014',data=df)
# Out:
# <Axes: xlabel='capacity_mw', ylabel='generation_gwh_2014'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='capacity_mw',y='generation_gwh_2015',data=df)
# Out:
# <Axes: xlabel='capacity_mw', ylabel='generation_gwh_2015'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='capacity_mw',y='generation_gwh_2016',data=df)
# Out:
# <Axes: xlabel='capacity_mw', ylabel='generation_gwh_2016'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='capacity_mw',y='generation_gwh_2017',data=df)
# Out:
# <Axes: xlabel='capacity_mw', ylabel='generation_gwh_2017'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='capacity_mw',y='generation_gwh_2018',data=df)
# Out:
# <Axes: xlabel='capacity_mw', ylabel='generation_gwh_2018'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='capacity_mw',y='generation_gwh_2019',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 2
#       1 plt.figure(figsize=(8,4))
# ----> 2 sns.scatterplot(x='capacity_mw',y='generation_gwh_2019',data=df)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:754, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     751 if not p.has_xy_data:
#     752     return ax
# --> 754 p._attach(ax)
#     756 # Other functions have color as an explicit param,
#     757 # and we should probably do that here too
#     758 color = kwargs.pop("color", None)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1262, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1260                 order = None
#    1261             seed_data = categorical_order(seed_data, order)
# ...

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='capacity_mw',y='latitude',data=df)
# Out:
# <Axes: xlabel='capacity_mw', ylabel='latitude'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2013',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2013'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2014',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2014'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2015',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2015'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2016',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2016'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2017',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2017'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2018',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='generation_gwh_2018'>

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x='primary_fuel',y='generation_gwh_2019',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[89], line 2
#       1 plt.figure(figsize=(8,4))
# ----> 2 sns.scatterplot(x='primary_fuel',y='generation_gwh_2019',data=df)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:754, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     751 if not p.has_xy_data:
#     752     return ax
# --> 754 p._attach(ax)
#     756 # Other functions have color as an explicit param,
#     757 # and we should probably do that here too
#     758 color = kwargs.pop("color", None)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1262, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1260                 order = None
#    1261             seed_data = categorical_order(seed_data, order)
# ...

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='primary_fuel',y='latitude',data=df)
# Out:
# <Axes: xlabel='primary_fuel', ylabel='latitude'>

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='capacity_mw',y='primary_fuel',data=df)
# Out:
# <Axes: xlabel='capacity_mw', ylabel='primary_fuel'>

# %%
sns.barplot(x = countries_plant.index, y = countries_plant)
plt.xticks(rotation = 90)
plt.title('Country Designation')
plt.ylabel('Number of Power Plant')
plt.xlabel('Countries');

# %%
sns.scatterplot(x=global_power_plant_df.capacity_mw,y=global_power_plant_df.primary_fuel,s=150)
plt.title('Type of power plant and capacity');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.scatterplot(x=global_power_plant_df.capacity_mw,y=global_power_plant_df.primary_fuel,s=150)
#       2 plt.title('Type of power plant and capacity')
#
# NameError: name 'global_power_plant_df' is not defined
