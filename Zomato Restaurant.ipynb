# %%
# Zomato Restaurant Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\Dell\Downloads\zomato (1).csv",encoding='unicode_escape')

# %%
df.head(51)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df[['Restaurant ID', 'Restaurant Name', 'City']]
# Out:
#       Restaurant ID           Restaurant Name              City
# 0           6317637          Le Petit Souffle       Makati City
# 1           6304287          Izakaya Kikufuji       Makati City
# 2           6300002    Heat - Edsa Shangri-La  Mandaluyong City
# 3           6318506                      Ooma  Mandaluyong City
# 4           6314302               Sambo Kojin  Mandaluyong City
# ...             ...                       ...               ...
# 9546        5915730              NamlÛ± Gurme         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±         ÛÁstanbul
# 9548        5915807                     Huqqa         ÛÁstanbul
# 9549        5916112              Aôôk Kahve         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery         ÛÁstanbul
#
# [9551 rows x 3 columns]

# %%
df['new rating'] = df['Aggregate rating']*2
df.head(10)
# Out:
#    Restaurant ID                           Restaurant Name  Country Code  \
# 0        6317637                          Le Petit Souffle           162
# 1        6304287                          Izakaya Kikufuji           162
# 2        6300002                    Heat - Edsa Shangri-La           162
# 3        6318506                                      Ooma           162
# 4        6314302                               Sambo Kojin           162
# 5       18189371                              Din Tai Fung           162
# 6        6300781                                Buffet 101           162
# 7        6301290                                   Vikings           162
# 8        6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9        6314987                                  Locavore           162
#
#                City                                            Address  \
# 0       Makati City  Third Floor, Century City Mall, Kalayaan Avenu...
# ...

# %%
df.sort_values('Votes', ascending=False)
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 728           51705                       Toit             1  Bangalore
# 735           51040                   Truffles             1  Bangalore
# 3994         308322           Hauz Khas Social             1  New Delhi
# 2412          20404                  Peter Cat             1    Kolkata
# 739           56618  AB's - Absolute Barbecues             1  Bangalore
# ...             ...                        ...           ...        ...
# 1016       18446428                KitchenYard             1  Faridabad
# 1015       18480389                  Fritrolla             1  Faridabad
# 7836       18499493                    Zombiez             1  New Delhi
# 7835       18424192       Zaika Chicken Corner             1  New Delhi
# 4524       18458655    Singh Chinese Fast Food             1  New Delhi
#
#                                                 Address  \
# ...

# %%
ratings = df.groupby(['Aggregate rating','Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
df['Cuisines'].value_counts().head(10)
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: count, dtype: int64

# %%
restt = df['City']=='Bangalore'
df[restt]
# Out:
#      Restaurant ID                   Restaurant Name  Country Code       City  \
# 726          50943                  Sultans of Spice             1  Bangalore
# 727          58268  The Fatty Bao - Asian Gastro Bar             1  Bangalore
# 728          51705                              Toit             1  Bangalore
# 729       18162866               Three Dots & A Dash             1  Bangalore
# 730       18407918                  Bombay Brasserie             1  Bangalore
# 731          56464                  Glen's Bakehouse             1  Bangalore
# 732       18221572                            Onesta             1  Bangalore
# 733       18359919                            Onesta             1  Bangalore
# 734       18439634                ECHOES Koramangala             1  Bangalore
# 735          51040                          Truffles             1  Bangalore
# 736          54162                   The Black Pearl             1  Bangalore
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
sns.heatmap(df.isnull().sum().to_frame())
# Out:
# <Axes: >

# %%
restt = df['City']=='Bangalore'
df[restt].groupby('Restaurant Name')['Aggregate rating'].agg('sum').plot(kind='bar')
# Out:
# <Axes: xlabel='Restaurant Name'>

# %%
plt.figure(figsize = [10,6])
sns.countplot(x = df['Has Online delivery'])
plt.title('Restaurant having online delivery or Not')
# Out:
# Text(0.5, 1.0, 'Restaurant having online delivery or Not')

# %%
plt.figure(figsize = [10,6])
sns.countplot(x = df['Has Table booking'])
plt.title('Restaurant having table Booking or Not')
# Out:
# Text(0.5, 1.0, 'Restaurant having table Booking or Not')

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating Count',data=ratings)
plt.show()

# %%
costly_zomato = df.nlargest(25, 'Average Cost for two')
costly_zomato
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 9283        7402935                                      Skye            94
# 9284        7410290                  Satoo - Hotel Shangri-La            94
# 9287        7420899                                Sushi Masa            94
# 9289        7421967                            3 Wise Monkeys            94
# 9294        7422489               Avec Moi Restaurant and Bar            94
# 9288       18352452                Lucky Cat Coffee & Kitchen            94
# 9295       18386856                                   Onokabe            94
# 9278        7423482                                Lemongrass            94
# 9285       18391256                                     MONKS            94
# 9279        7422633                          Talaga Sampireun            94
# 9281       18425821                                      OJJU            94
# ...

# %%
df[(df['Average Cost for two']<10000) & (df['Aggregate rating']!=0)].plot.scatter(x = 'Average Cost for two', y = 'Aggregate rating', figsize=(15,7), title="The dependence of the rating on the price for two")
plt.show()

# %%
scatter_price_rating = df.plot.scatter('Aggregate rating','Votes',figsize = (7,5))
plt.title("Relationship betweeen Votes and Aggregate rating")
plt.show()

# %%
n = ['Price range', 'Aggregate rating', 'Votes', 'Average Cost for two']
sns.pairplot(df[n])
plt.show()

# %%
# Out:
# ['Price range', 'Aggregate rating', 'Votes', 'Average Cost for two']

# %%
df[["Average Cost for two"]].mean()
# Out:
# Average Cost for two    1199.210763
# dtype: float64
